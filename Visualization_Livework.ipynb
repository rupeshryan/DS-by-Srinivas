# %% [markdown]
# <a href="https://colab.research.google.com/github/rupeshryan/DS-by-Srinivas/blob/main/Visualization_Livework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x=  [-1,3,6]

# %%
y= [10,3,7]

# %%
fig = plt.figure(figsize=(15,3))

plt.plot(x,y)
plt.xlim(0,10)
plt.ylim(-4,9)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Line Plot')
plt.suptitle('Sales Comparison', size=18, y=1.05)
# Out:
# Text(0.5, 1.05, 'Sales Comparison')

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)    #fig.savefig('example.png', dpi=300, bbox_inches='tight')

# %%
# More than one Axes with plt.subplots, then the second item in the tuple is a NumPy array containing all the Axes
fig, axs = plt.subplots(2, 4)

# %% [markdown]
# ## Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt     #once we call a lib we dont have to  again in same notebook

mtcars = pd.read_csv('/content/mtcars.csv')

# %%
mtcars.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
mtcars.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
mtcars.shape
# Out:
# (32, 11)

# %%
mtcars.size
# Out:
# 352

# %%
pd.crosstab(mtcars.gear, mtcars.cyl)   #if we want to generate a frequency table between to discrete variable/columns or categorical variable, we use crosstable
# Out:
# cyl   4  6   8
# gear
# 3     1  2  12
# 4     8  4   0
# 5     2  1   2

# %%
#plotting the cross table on bar plot
pd.crosstab(mtcars.gear, mtcars.cyl).plot(kind='bar')
# Out:
# <Axes: xlabel='gear'>

# %%
#PIe plot
mtcars.gear.value_counts()  #this gives the frequecy of repeating value in gear column
mtcars.gear.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='gear'>

# %%
#Scatter plot
plt.scatter(mtcars.mpg,mtcars.qsec)

# %%
#Histogram
plt.hist(mtcars.mpg)
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
#how to change colour and other features on histogram
plt.hist(mtcars.mpg, facecolor= 'green', edgecolor= 'black', bins= 5)
# Out:
# (array([ 6., 12.,  8.,  2.,  4.]),
#  array([10.4, 15.1, 19.8, 24.5, 29.2, 33.9]),
#  <BarContainer object of 5 artists>)

# %%
#Box plot
plt.boxplot(mtcars.mpg, vert= False)
#help(plt.boxplot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f8eb868e8c0>,
#   <matplotlib.lines.Line2D at 0x7f8eb868eb60>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f8eb868ee00>,
#   <matplotlib.lines.Line2D at 0x7f8eb868f0a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f8eb868e620>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f8eb868f340>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f8eb868f5e0>],
#  'means': []}

# %%
plt.boxplot(mtcars.mpg, vert= True); plt.ylabel='MPG' ;plt.xlabel('Box Plot');plt.title('BOX')
# Out:
# Text(0.5, 1.0, 'BOX')

# %%
#Violin plot
plt.violinplot(mtcars.mpg, vert = False)
#help(plt.violinplot)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7f8eb875ff40>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7f8eb875fe80>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7f8eb85a4550>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7f8eb85a48b0>}

# %% [markdown]
# # Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### UniVariate - "one variable" data visualization

# %%
#Strip plot
sns.stripplot(y= 'tip', data= tips, jitter= True)  #jitter will prevent the datat points to be in single line so that we can see better
plt.show()

# %%
#grouping with strip plot
sns.stripplot(x='day', y='tip', data=tips)
plt.show()

# %%
sns.stripplot(x= "day", y="tip",data=tips, size=4, jitter=False)
plt.show()

# %%
#Swarm Plot
sns.swarmplot(x='day',y='tip', data= tips)
plt.show()

# %%
sns.swarmplot(x='day', y='tip', data=tips, hue='sex')    #here we are adding sex as another variable to differentiate tips based on gender
plt.show()

# %%
sns.swarmplot(x='tip', y='day', data=tips, hue='sex',orient='h')    #changing orientation
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
 #Box Plot
 sns.boxplot(x='day', y='tip', data= tips)
 plt.show()

# %%
#Violin plot
sns.violinplot(x='day', y='tip', data= tips)
plt.show()

# %%
#putting the plots side by side
plt.subplot(1,2,1)    #1,2 is partition and 1 is position
sns.boxplot(x='day', y='tip', data= tips)
plt.subplot(1,2,2)
sns.violinplot(x='day', y='tip', data= tips)
plt.show()

# %%
#cominbing the plot
sns.violinplot(x='day', y='tip', data=tips, inner=None,color='lightgray')
sns.stripplot(x='day', y='tip', data=tips, size=4,jitter=True)
plt.show()

# %% [markdown]
# ## Bi-variate - two variable visualition

# %%
#Joint plot
sns.jointplot(x='total_bill', y= 'tip', data=tips)
plt.show()

# %%
#density plot
sns.jointplot(x= 'total_bill', y='tip', data= tips, kind = 'kde')    #kde  is kernal density estimation
plt.show()

# %%
#pair plot
sns.pairplot(tips)

# %%
sns.pairplot(tips , hue='sex')

# %% [markdown]
# ## Titanic data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline

warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('/content/train.csv')
data.head()

#Survived (1- yes and 0- no) class - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd) name - Name sex - Sex age - Age sibsp - Number of Siblings/Spouses Aboard
#parch - Number of Parents/Children Aboard ticket - Ticket Number fare - Passenger Fare cabin - Cabin
#embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.groupby('Survived')['PassengerId'].count()   #proportion of target(survived)
# Out:
# Survived
# 0    549
# 1    342
# Name: PassengerId, dtype: int64

# %%
#Visual Exploration

# %%
f, ax = plt.subplots(figsize= (12,6))
sns.boxplot(x= 'Survived', y='Age', data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
f, ax= plt.subplots(figsize= (10,8))
sns.barplot(x='Sex', y='Survived', data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
f, ax= plt.subplots(figsize=(8,5))
sns.boxplot(x='Sex', y='Age', hue= "Survived", data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.barplot(x='Pclass', y='Survived', data=data)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
sns.barplot(x='Pclass', y='Survived', hue='Sex', data= data)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
sns.barplot(x='SibSp', y='Survived', data= data)
# Out:
# <Axes: xlabel='SibSp', ylabel='Survived'>

# %%
sns.barplot(x='Parch', y='Survived', data= data)
# Out:
# <Axes: xlabel='Parch', ylabel='Survived'>

# %%
survived= data.loc[data.Survived==1,'Age'].dropna()
sns.distplot(survived)
plt.title('Survived')
# Out:
# Text(0.5, 1.0, 'Survived')

# %%
not_survived = data.loc[data.Survived==0,'Age'].dropna()
sns.distplot(not_survived)
plt.title('Not Survived')
# Out:
# Text(0.5, 1.0, 'Not Survived')

# %%
sns.pairplot(data.dropna())

# %%
sns.pairplot(data.dropna(), hue='Sex')

# %%
 # Pclass vs Survive
grid = sns.FacetGrid(data, col='Survived',row='Pclass')
grid.map(plt.hist, 'Age', alpha=.5, bins=20)
grid.add_legend()

# %%
#Most of the Passengers embarked from Southampton

sns.distplot(a=data[data['Embarked']=='C']['Survived'],bins=3,kde=False)
plt.title("Cherbourg")
plt.xticks([0,1])
plt.show()
plt.title("QueensTown")
sns.distplot(a=data[data['Embarked']=='Q']['Survived'],bins=3,kde=False)
plt.xticks([0,1])

plt.show()
plt.title("Southampton")
sns.distplot(a=data[data['Embarked']=='S']['Survived'],bins=3,kde=False)
plt.xticks([0,1])

plt.show()

# %%
figbi, axesbi = plt.subplots(2, 4, figsize=(16, 10))
data.groupby('Pclass')['Survived'].mean().plot(kind='barh',ax=axesbi[0,0],xlim=[0,1])
data.groupby('SibSp')['Survived'].mean().plot(kind='barh',ax=axesbi[0,1],xlim=[0,1])
data.groupby('Parch')['Survived'].mean().plot(kind='barh',ax=axesbi[0,2],xlim=[0,1])
data.groupby('Sex')['Survived'].mean().plot(kind='barh',ax=axesbi[0,3],xlim=[0,1])
data.groupby('Embarked')['Survived'].mean().plot(kind='barh',ax=axesbi[1,0],xlim=[0,1])
sns.boxplot(x="Survived", y="Age", data=data,ax=axesbi[1,1])
sns.boxplot(x="Survived", y="Fare", data=data,ax=axesbi[1,2])
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>
